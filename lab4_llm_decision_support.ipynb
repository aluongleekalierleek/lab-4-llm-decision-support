# %% [markdown]
# <a href="https://colab.research.google.com/github/aluongleekalierleek/lab-4-llm-decision-support/blob/main/lab4_llm_decision_support.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata

API_KEY = userdata.get("GROQ_API_KEY")
print("API key loaded successfully!")
# Out:
# API key loaded successfully!

# %%
from openai import OpenAI

client = OpenAI(
    api_key=API_KEY,
    base_url="https://api.groq.com/openai/v1",   # Groq’s endpoint
)

MODEL = "llama-3.3-70b-versatile"
print("Client ready.")
# Out:
# Client ready.

# %%
def ask_llm(prompt):
    response = client.chat.completions.create(
        model=MODEL,
        messages=[{"role": "user", "content": prompt}],
    )
    return response.choices[0].message.content

print(ask_llm("what is the best way to improve grades since we are left with only 2 weeks to final exams, please i need the most top effective ones"))
# Out:
# With only 2 weeks left before the final exams, it's essential to have a focused approach to improve your grades. Here are the top effective ways to boost your grades in a short span:
#
# **Top 5 Study Strategies:**
#
# 1. **Create a Study Schedule**: Plan out your study sessions for the next 2 weeks, setting specific goals for each day. Allocate dedicated blocks of time for each subject, and make sure to include breaks to avoid burnout.
# 2. **Focus on Weak Areas**: Identify your weaknesses in each subject and prioritize studying those areas. Use your previous exams, quizzes, or assignments to pinpoint where you need improvement.
# 3. **Active Recall and Practice**: Engage in active recall by summarizing notes in your own words, creating concept maps, or making flashcards. Practice past exams, quizzes, or sample questions to reinforce your understanding.
# 4. **Use Active Learning Techniques**: Employ techniques like:
# 	* Self-quizzing
# 	* Mnemonics
# 	* Mind maps
# 	* Chunking (breaking down complex information into smaller chunks)
# 	* Interleaving (switching between different types of material to deepen understanding)
# 5. **Review and Reflect Daily**: Set aside time each day to review what you've studied, and reflect on what you've learned. Ask yourself:
# 	* What did I learn today?
# 	* What didn't I understand?
# 	* What do I need to review again?
#
# **Additional Tips:**
#
# * **Get Enough Sleep**: Aim for 7-9 hours of sleep each night to help consolidate information and improve focus.
# * **Stay Organized**: Keep all your study materials, including notes, assignments, and practice exams, organized and easily accessible.
# * **Seek Help**: Reach out to teachers, classmates, or tutors for help with specific topics or concepts you're struggling with.
# * **Use Technology Strategically**: Utilize digital tools, such as flashcard apps, study planners, or online resources, to supplement your studying.
# * **Stay Motivated**: Remind yourself of your goals, and celebrate small victories along the way to stay motivated and focused.
#
# **Time Management:**
#
# * ** Allocate 4-6 hours per day** for studying, with breaks in between.
# * **Use the Pomodoro Technique**: Study in 25-minute focused intervals, followed by a 5-minute break.
# * **Review and adjust your schedule** regularly to ensure you're on track to meet your goals.
#
# By implementing these strategies, you'll be well on your way to improving your grades in the short time left before the final exams. Stay focused, stay motivated, and you'll achieve your goals!

# %%
with open("requirements.txt", "w") as f:
    f.write("openai\npython-dotenv\npandas\nmatplotlib\n")

# %%
def ask_llm(user_prompt, system_prompt="You are a helpful assistant.",
            temperature=0.7, max_tokens=500):
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user",   "content": user_prompt},
        ],
        temperature=temperature,
        max_tokens=max_tokens,
    )

    print("Usage:", response.usage)
    return response.choices[0].message.content


print(ask_llm("What is 2 + 2?"))
# Out:
# Usage: CompletionUsage(completion_tokens=9, prompt_tokens=49, total_tokens=58, completion_tokens_details=None, prompt_tokens_details=None, queue_time=0.178559644, prompt_time=0.001462306, completion_time=0.018010101, total_time=0.019472407)
# 2 + 2 = 4.

# %% [markdown]
# 1. Role of the system provides the guidelines or the tone for the model. E.g., “You are an expert in physics.”
# The user role is the query itself. E.g., “Tell me about gravity.”
#
# 2. Token refers to a chunk of text (word or part of a word). The pricing from the API providers is based on tokens because queries can be short and very lengthy. Pricing on the basis of tokens makes sense since short questions would cost less than lengthy essays.
