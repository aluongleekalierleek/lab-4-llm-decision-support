# %%
from google.colab import userdata

API_KEY = userdata.get("GROQ_API_KEY")
print("API key loaded successfully!")
# Out:
# API key loaded successfully!

# %%
from openai import OpenAI

client = OpenAI(
    api_key=API_KEY,
    base_url="https://api.groq.com/openai/v1",   # Groq’s endpoint
)

MODEL = "llama-3.3-70b-versatile"
print("Client ready.")
# Out:
# Client ready.

# %%
def ask_llm(prompt):
    response = client.chat.completions.create(
        model=MODEL,
        messages=[{"role": "user", "content": prompt}],
    )
    return response.choices[0].message.content

print(ask_llm("what is the best way to improve grades since we are left with only 2 weeks to final exams, please i need the most top effective ones"))
# Out:
# With only 2 weeks left before the final exams, it's essential to focus on the most effective strategies to improve your grades. Here are the top effective ways to boost your grades in a short span:
#
# 1. **Create a Study Schedule**: Plan out your study routine, setting specific goals and deadlines for each subject. Allocate more time to weaker areas and make sure to include regular breaks to avoid burnout.
# 2. **Prioritize Weak Areas**: Identify the topics you struggle with the most and focus on those first. Use your study schedule to dedicate extra time to reviewing and practicing those areas.
# 3. **Active Recall**: Instead of simply re-reading your notes, actively recall the information by:
# 	* Creating flashcards
# 	* Making concept maps
# 	* Self-testing with practice quizzes or past exams
# 	* Summarizing notes in your own words
# 4. **Practice Past Exams and Quizzes**: Get familiar with the exam format, question types, and time management by practicing past exams and quizzes. This will help you:
# 	* Identify common question patterns
# 	* Develop time management skills
# 	* Improve your problem-solving skills
# 5. **Focus on High-Yield Topics**: Identify the most critical topics in each subject and focus on those first. These topics are often the ones that are most frequently tested or carry the most weight in the exam.
# 6. **Use Active Learning Techniques**: Engage with your study materials by:
# 	* Watching video lectures or online tutorials
# 	* Participating in online forums or study groups
# 	* Creating concept songs or rhymes
# 	* Teaching someone else what you've learned
# 7. **Get Enough Sleep and Stay Healthy**: Take care of your physical and mental well-being by:
# 	* Getting 7-9 hours of sleep each night
# 	* Eating nutritious food and staying hydrated
# 	* Exercising regularly to reduce stress and improve focus
# 8. **Review and Reflect Daily**: Set aside time each day to review what you've studied and reflect on what you've learned. This will help you:
# 	* Identify areas that need improvement
# 	* Consolidate information in your long-term memory
# 	* Adjust your study schedule as needed
# 9. **Seek Help When Needed**: Don't hesitate to ask for help if you're struggling with a particular concept or subject. Reach out to:
# 	* Teachers or instructors
# 	* Classmates or study groups
# 	* Online resources or tutoring services
# 10. **Stay Motivated and Focused**: Remind yourself of your goals and why you're working hard. Use positive self-talk, rewards, and incentives to stay motivated and focused.
#
# Additionally, consider the following tips to make the most of your remaining time:
#
# * Avoid cramming and trying to study everything at once. Break your study material into manageable chunks.
# * Use technology to your advantage, such as flashcard apps or online study tools.
# * Eliminate distractions, such as turning off your phone or finding a quiet study space.
# * Stay organized and keep all your study materials, including notes and practice exams, in one place.
#
# By following these effective strategies, you can make the most of your remaining time and improve your grades before the final exams.

# %%
with open("requirements.txt", "w") as f:
    f.write("openai\npython-dotenv\npandas\nmatplotlib\n")
